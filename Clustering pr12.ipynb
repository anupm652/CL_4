# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
# Import the iris dataset
iris = datasets.load_iris()
X = iris.data
y = iris.target

# %%
# Determine the optimal number of clusters using the Elbow method
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss, 'bx-')
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Based on the Elbow plot, choose the optimal number of clusters
# For this example, let's assume the optimal number is 3
optimal_clusters = 3

# %%
# K-Means Clustering with the optimal number of clusters
kmeans = KMeans(n_clusters=optimal_clusters, random_state=0)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=3, random_state=0)

# %%
# Predict the cluster for each data point
y_kmeans = kmeans.predict(X)

# %%
# Visualizing the clusters
plt.figure(figsize=(10, 6))
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, cmap='viridis')
plt.title('K-Means Clustering of Iris Dataset')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.show()

# %%
# Visualizing the cluster centers
plt.figure(figsize=(10, 6))
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, cmap='viridis')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='red', marker='*')
plt.title('K-Means Clustering Centers of Iris Dataset')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.show()

# %% [markdown]
# - Clustering: Clustering or cluster analysis is a machine learning technique, which groups the unlabelled dataset. It can be defined as "A way of grouping the data points into different clusters, consisting of similar data points. The objects with the possible similarities remain in a group that has less or no similarities with another group."
#     It does it by finding some similar patterns in the unlabelled dataset such as shape, size, color, behavior, etc., and divides them as per the presence and absence of those similar patterns.
#
#     It is an unsupervised learning method, hence no supervision is provided to the algorithm, and it deals with the unlabeled dataset.
#
#     Market Segmentation
# Statistical data analysis
# Social network analysis
# Image segmentation
# Anomaly detection, etc.
#
# - K-Means: K-Means Clustering is an Unsupervised Learning algorithm, which groups the unlabeled dataset into different clusters.
#     It allows us to cluster the data into different groups and a convenient way to discover the categories of groups in the unlabeled dataset on its own without the need for any training.
#
#
#
# - Elbow Method: Determine the optimal number of clusters (K) for K-means
#     Elbow point signifies the trade-off between model complexity and variance explanation. Beyond the elbow, adding more clusters may not significantly improve results.
#
#
#
# ![image.png](attachment:image.png)
